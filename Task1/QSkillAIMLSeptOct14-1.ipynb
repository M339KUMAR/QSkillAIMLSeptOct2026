# %% [markdown]
# <a href="https://colab.research.google.com/github/M339KUMAR/QSkillAIMLSeptOct2026/blob/main/Task1/QSkillAIMLSeptOct14-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Email Classification

# %%
from datasets import load_dataset

ds = load_dataset("legacy107/spamming-email-classification")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/680 [00:00<?, ?B/s]
# data/train-00000-of-00001-14eed08eb524d6(…): reconstructing file:   0%|          |  0.00B / 4.00MB
# data/train-00000-of-00001-14eed08eb524d6(…): downloading bytes:           |  0.00B
# data/val-00000-of-00001-2305296c7422e529(…): reconstructing file:   0%|          |  0.00B /  457kB
# data/val-00000-of-00001-2305296c7422e529(…): downloading bytes:           |  0.00B
# data/test-00000-of-00001-622decef5f682f6(…): reconstructing file:   0%|          |  0.00B /  507kB
# data/test-00000-of-00001-622decef5f682f6(…): downloading bytes:           |  0.00B
# ...
# Generating test split:   0%|          | 0/570 [00:00<?, ? examples/s]

# %%
ds["train"].to_csv("email_train.csv")
ds["test"].to_csv("email_test.csv")
# Out:
# ...
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 922557
